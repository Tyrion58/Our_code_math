# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlp

# %%
global_data = pd.read_csv('./data/global_data.csv')
global_data.drop('Unnamed: 0', axis=1, inplace=True)
global_data
# Out:
#        dt  mean_temp
# 0    1900  20.718605
# 1    1901  21.954773
# 2    1902  21.387267
# 3    1903  21.663932
# 4    1904  21.202406
# ..    ...        ...
# 109  2009  20.378652
# 110  2010  20.405177
# 111  2011  20.417404
# 112  2012  20.878080
# 113  2013  22.123639
#
# [114 rows x 2 columns]

# %%
plt.plot(global_data['dt'], global_data['mean_temp'], color='r')
plt.ylabel('global temperature')
plt.xlabel('year')
plt.title('Global average temperature variation')
plt.show()

# %%
plt.hist(global_data['mean_temp'], bins=20, edgecolor='b')
plt.xlabel("temperature")
plt.title("Global average temperature frequency")
plt.show()

# %%
north_data = pd.read_csv('./data/north_data.csv')
north_data.drop('Unnamed: 0', axis=1, inplace=True)
north_data
# Out:
#        dt  mean_temp
# 0    1900  15.199360
# 1    1901  19.056808
# 2    1902  18.049334
# 3    1903  18.688032
# 4    1904  18.136160
# ..    ...        ...
# 109  2009  16.448218
# 110  2010  16.432279
# 111  2011  16.669977
# 112  2012  17.220810
# 113  2013  19.267257
#
# [114 rows x 2 columns]

# %%
plt.plot(north_data['dt'], north_data['mean_temp'], color='r')
plt.ylabel('North temperature')
plt.xlabel('Year')
plt.title('North temperate zone average temperature variation')
plt.show()

# %%
plt.hist(north_data['mean_temp'], bins=20, edgecolor='b')
plt.xlabel("temperature")
plt.title("North temperate zone average temperature frequency")
plt.show()

# %%
south_data = pd.read_csv('./data/sorth_data.csv')
south_data.drop('Unnamed: 0', axis=1, inplace=True)
south_data
# Out:
#        dt  mean_temp
# 0    1900  19.365263
# 1    1901  18.416839
# 2    1902  18.346779
# 3    1903  18.502522
# 4    1904  17.883613
# ..    ...        ...
# 109  2009  17.851027
# 110  2010  17.859195
# 111  2011  17.886904
# 112  2012  18.536476
# 113  2013  17.563722
#
# [114 rows x 2 columns]

# %%
plt.plot(south_data['dt'], south_data['mean_temp'], color='r')
plt.ylabel('South temperature')
plt.xlabel('Year')
plt.title('South temperate zone average temperature variation')
plt.show()

# %%
plt.hist(south_data['mean_temp'], bins=20, edgecolor='b')
plt.xlabel("temperature")
plt.title("South temperate zone average temperature frequency")
plt.show()

# %%
hot_data = pd.read_csv('./data/hot_data.csv')
hot_data.drop('Unnamed: 0', axis=1, inplace=True)
hot_data
# Out:
#        dt  mean_temp
# 0    1900  24.356499
# 1    1901  25.201248
# 2    1902  25.012438
# 3    1903  24.801590
# 4    1904  24.688570
# ..    ...        ...
# 109  2009  25.484136
# 110  2010  25.537677
# 111  2011  25.157742
# 112  2012  25.426810
# 113  2013  25.708844
#
# [114 rows x 2 columns]

# %%
plt.plot(hot_data['dt'], hot_data['mean_temp'], color='r')
plt.ylabel('Tropic temperature')
plt.xlabel('Year')
plt.title('Tropic average temperature variation')
plt.show()

# %%
plt.hist(hot_data['mean_temp'], bins=20, edgecolor='b')
plt.xlabel("temperature")
plt.title("Tropic temperature frequency")
plt.show()
